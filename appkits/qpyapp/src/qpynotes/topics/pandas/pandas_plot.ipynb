# %%
import pandas as pd
import matplotlib.pyplot as plt

drinks_data = pd.read_csv('./data/drinks.csv')
print(drinks_data)
print(drinks_data.head(10))
print(drinks_data.tail(10))
print(drinks_data.describe())
drinks_data['total_litres_of_pure_alcohol'].plot()
plt.show()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...
